# %%
import sys
# sys.path is a list of absolute path strings
sys.path.append('../')

# %% [markdown]
# # Offense data

# %% [markdown]
# ## Passing Data

# %%
from components.get_data import GetData

# %%
with GetData() as get_data:
    passing_data = get_data.get_passing_data(2000,2023)

# %%
passing_data
# Out:
#                  team  att  cmp cmp_percent yds_per_att pass_td  td int  rate
# 0            JetsJets  637  352        55.3         6.3    4023  23  29  67.5  \
# 1      PackersPackers  600  348          58         6.5    3916  21  16  78.2
# 2            RamsRams  587  380        64.7         9.4    5492  37  23  99.7
# 3          49ers49ers  583  366        62.8         7.6    4400  32  10    97
# 4        ChiefsChiefs  582  342        58.8         7.6    4408  29  15  88.5
# ..                ...  ...  ...         ...         ...     ...  ..  ..   ...
# 729      RavensRavens  488  300        61.5         6.6    3202  19  13  82.5
# 730  PanthersPanthers  457  267        58.4         7.1    3246  16  13  80.2
# 731      TitansTitans  456  285        62.5         7.1    3227  16  11  85.3
# 732    FalconsFalcons  415  257        61.9           7    2927  17   9  87.7
# 733        BearsBears  377  223        59.2         6.9    2598  19  15  80.3
#
# ...

# %% [markdown]
# ## Rushing

# %%
#https://www.nfl.com/stats/team-stats/offense/rushing/2010/reg/all
