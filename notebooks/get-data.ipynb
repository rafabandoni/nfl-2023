# %%
import sys
# sys.path is a list of absolute path strings
sys.path.append('../')

# %%
import pandas as pd

# %%
OFFENSE_PATH = '../data/offense/'
DEFENSE_PATH = '../data/defense/'
SPECIAL_TEAMS_PATH = '../data/special-teams/'

# %% [markdown]
# # Downloading Data

# %%
from src.get_data.get_data import ScrapData

# %%
with ScrapData() as scrap_data:
    scrap_data.get_data(2000,2023)
# Out:
# ...
# module 'src.get_data.columns' has no attribute 'special'
# Get data finished.

# %% [markdown]
# # To dos:
# - Add a path when saving data for specific stat
# - Solve: module 'src.get_data.columns' has no attribute 'special' when importing special teams
# - Maybe will have some more problem with the '-' in 'special-teams'
#
# - Unduplicate name on team column (BuccaneersBuccaneers)

# %% [markdown]
# # Reading and treating data

# %% [markdown]
# ## Offense

# %% [markdown]
# ## Defense

# %% [markdown]
# ## Special Teams

# %%
pd.read_parquet('../data/offense_passing.parquet')
# Out:
#                     team  att  cmp cmp_percent yds_per_att pass_td  td int
# 1   BuccaneersBuccaneers  751  499        66.4         6.3    4746  26  10  \
# 2       ChargersChargers  711  485        68.2         6.7    4791  26  10
# 3         VikingsVikings  672  448        66.7         7.2    4818  30  15
# 4     CardinalsCardinals  664  433        65.2           6    3966  17  17
# 5           ChiefsChiefs  651  435        66.8         8.1    5250  41  12
# 6               JetsJets  627  357        56.9         6.4    4040  15  14
# 7         BengalsBengals  610  418        68.5         7.4    4520  35  12
# 8             ColtsColts  604  398        65.9         6.4    3854  17  20
# 9         JaguarsJaguars  596  394        66.1           7    4148  25   9
# 10            LionsLions  588  383        65.1         7.6    4444  29   7
# 11        RaidersRaiders  586  359        61.3         7.1    4182  28  17
# ...

# %%
pd.read_parquet('../data/offense_rushing.parquet')
# Out:
#                     team  att rush_yds  ypc  td 20plus 40plus  lng rush_fst
# 1         FalconsFalcons  559     2718  4.9  17     17      4   44      152  \
# 2             BearsBears  558     3014  5.4  18     20      8   67      148
# 3           EaglesEagles  544     2509  4.6  32     17      2  42T      161
# 4   CommandersCommanders  538     2143    4   9      8      0   33      124
# 5           BrownsBrowns  532     2490  4.7  19     21      1   41      142
# 6         CowboysCowboys  531     2298  4.3  24     17      3   57      129
# 7           RavensRavens  526     2720  5.2  14     18      3  79T      167
# 8           GiantsGiants  520     2519  4.8  21     15      2   68      150
# 9             49ers49ers  504     2360  4.7  20     19      4   71      132
# 10      SteelersSteelers  500     2073  4.2  16      8      0   36      129
# 11          TitansTitans  487     2131  4.4  16     13      4   56      104
# ...
